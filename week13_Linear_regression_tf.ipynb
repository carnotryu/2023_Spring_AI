# %% [markdown]
# ### Liner Regression

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import numpy as np
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
x_train = [1, 2, 3]

# %%
y_train = [2+0.1, 4-0.2, 6+0.15]

# %%
plt.plot(x_train, y_train,'.-')
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# ### Initialization (초기화)

# %%
# w, b 초기값 설정 - 자유롭게 변경해볼 것
w0 = 7;
b0 = -10;
W = tf.Variable(w0*tf.ones([1]), name='weight')
b = tf.Variable(b0*tf.ones([1]), name='bias')

# %% [markdown]
# ### Hypothesis: xW + b

# %%
hypothesis = x_train * W + b

# %% [markdown]
# ### Cost Function 정의

# %%
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# %% [markdown]
# ### Optimizer 설정

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01) # learning_rate 값을 바꿔가며 테스트 해볼 것
train = optimizer.minimize(cost)

# %% [markdown]
# ### Launch the graph in a session

# %%
sess = tf.Session()

# %% [markdown]
# ### Initilizes global variables in the graph

# %%
sess.run(tf.global_variables_initializer())

# %% [markdown]
# ### Run!

# %%
# epoch: 반복횟수
nb_epoch = 2000

# %%
# w, b, cost 값의 변화를 저장할 변수 정의
vw = []
vb = []
vcost = []

# %%
for step in range(nb_epoch+1):
  sess.run(train)
  w1 = sess.run(W)[0] # slope
  b1 = sess.run(b)[0] # bias
  cost1 = sess.run(cost)
  vw.append(w1)
  vb.append(b1)
  vcost.append(cost1)
  if step % 100 == 0: # 100번마다 결과 출력해보기 (monitoring 목적)
    print(step, '--', cost1, '--', w1, '--', b1)
# Out:
# 0 -- 16.112978 -- 6.9343333 -- -9.999666
# 100 -- 9.173922 -- 5.5383186 -- -8.019924
# 200 -- 5.6778927 -- 4.7867856 -- -6.311521
# 300 -- 3.517561 -- 4.1960154 -- -4.968562
# 400 -- 2.1826074 -- 3.7316163 -- -3.9128733
# 500 -- 1.3576864 -- 3.366556 -- -3.0830052
# 600 -- 0.84793544 -- 3.079585 -- -2.430653
# 700 -- 0.53294045 -- 2.854 -- -1.9178452
# 800 -- 0.33829236 -- 2.6766694 -- -1.5147307
# 900 -- 0.2180118 -- 2.5372713 -- -1.1978465
# 1000 -- 0.14368592 -- 2.4276922 -- -0.94874704
# 1100 -- 0.09775708 -- 2.341553 -- -0.75293213
# 1200 -- 0.06937576 -- 2.2738397 -- -0.5990038
# 1300 -- 0.051837828 -- 2.2206104 -- -0.47800207
# 1400 -- 0.0410004 -- 2.1787674 -- -0.38288298
# 1500 -- 0.034303565 -- 2.145875 -- -0.30811128
# 1600 -- 0.03016533 -- 2.120019 -- -0.24933368
# 1700 -- 0.027608156 -- 2.0996935 -- -0.20312952
# 1800 -- 0.026027998 -- 2.0837162 -- -0.16680856
# 1900 -- 0.025051534 -- 2.071156 -- -0.13825722
# 2000 -- 0.024448132 -- 2.0612826 -- -0.11581262

# %%
w1 = sess.run(W)[0] # slope
b1 = sess.run(b)[0] # bias
str1 = 'y={:.3}x + {:.3}'.format(w1, b1)
print(w1, b1)
print(str1)
# Out:
# 2.0612826 -0.11581262
# y=2.06x + -0.116

# %%
# regression 결과 그려보기
plt.figure(1)
plt.plot(x_train, y_train,'o')
x1 = np.min(x_train)-1, np.max(x_train)+1
y1 = np.dot(w1,x1) + b1
plt.plot(x1, y1)
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.title(str1)
# Out:
# Text(0.5, 1.0, 'y=2.06x + -0.116')

# %%
# 학습하는 동안 b의 변화 보기
plt.plot(vb)
plt.grid()
plt.xlabel('epoch')
plt.ylabel('b')
# Out:
# Text(0, 0.5, 'b')

# %%
# 학습하는 동안 w의 변화 보기
plt.plot(vw)
plt.grid()
plt.xlabel('epoch')
plt.ylabel('w')
# Out:
# Text(0, 0.5, 'w')

# %%
# 학습하는 동안 cost의 변화 보기
plt.plot(vcost)
plt.grid()
plt.xlabel('epoch')
plt.ylabel('cost')
# Out:
# Text(0, 0.5, 'cost')
